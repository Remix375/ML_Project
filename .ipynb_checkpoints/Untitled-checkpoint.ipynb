# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
db = pd.read_csv("/home/remix375/Documents/Programming/ml/Unicauca-dataset-April-June-2019-Network-flows.csv")

# %%
db.describe()
# Out:
#        src_ip_numeric      src_port      dst_port         proto  \
# count    2.704839e+06  2.704839e+06  2.704839e+06  2.704839e+06
# mean     3.232268e+09  5.114658e+04  2.733782e+03  1.082042e+01
# std      7.156085e+02  1.317720e+04  9.206813e+03  5.478148e+00
# min      3.232266e+09  0.000000e+00  0.000000e+00  1.000000e+00
# 25%      3.232267e+09  4.977700e+04  5.300000e+01  6.000000e+00
# 50%      3.232268e+09  5.326100e+04  4.430000e+02  6.000000e+00
# 75%      3.232268e+09  5.901100e+04  4.430000e+02  1.700000e+01
# max      3.232269e+09  6.553500e+04  6.553500e+04  1.700000e+01
#
#        pktTotalCount  octetTotalCount        min_ps        max_ps  \
# count   2.704839e+06     2.704839e+06  2.704839e+06  2.704839e+06
# mean    8.916930e+01     1.070166e+05  5.822987e+01  1.249313e+03
# std     3.804669e+03     5.454587e+06  6.023631e+01  2.939242e+03
# min     1.000000e+00     2.800000e+01  2.800000e+01  2.800000e+01
# ...

# %%
db.head()
# Out:
#                            flow_key  src_ip_numeric         src_ip  src_port  \
# 0  3acee4f4ea001cd5e6d9584d4036b53d      3232266497  192.168.121.1        67
# 1  974ec5991b439c9a7176b88be0c90df0      3232266497  192.168.121.1        67
# 2  3acee4f4ea001cd5e6d9584d4036b53d      3232266497  192.168.121.1        67
# 3  974ec5991b439c9a7176b88be0c90df0      3232266497  192.168.121.1        67
# 4  cfa7c2740072befaa89c202499729e08      3232266497  192.168.121.1         0
#
#            dst_ip  dst_port  proto  pktTotalCount  octetTotalCount  min_ps  \
# 0  172.16.255.185        67     17             22             7620     328
# 1  172.16.255.186        67     17             17             5670     328
# 2  172.16.255.185        67     17             43            15124     328
# 3  172.16.255.186        67     17             30            10086     328
# 4    10.130.1.166         0      1              1               56      56
#
# ...

# %%
db["category"].unique()
# Out:
# array(['Network', 'Web', 'SoftwareUpdate', 'Unspecified', 'RPC', 'System',
#        'Cloud', 'Email', 'Media', 'Streaming', 'VoIP', 'Collaborative',
#        'Music', 'SocialNetwork', 'Video',
#        'Download-FileTransfer-FileSharing', 'Chat', 'VPN', 'RemoteAccess',
#        'Game', 'Database', 'Mining', 'Shopping', 'DataTransfer'],
#       dtype=object)

# %%
db.loc[db["category"] == "Streaming", "octetTotalCount"].mean()
# Out:
# 1387773.1540616245

# %%
db.loc[db["category"] == "Game", "octetTotalCount"].mean()
# Out:
# 192205.681372549

# %%
db.loc[db["category"] == "Web", "octetTotalCount"].mean()
# Out:
# 118847.43090500431

# %%
db["application_protocol"].unique()
# Out:
# array(['Unknown', 'HTTP', 'TLS', 'DNS', 'QUIC', 'IMAPS', 'STUN', 'SMTPS',
#        'POPS', 'Skype', 'BitTorrent', 'SMBv23', 'NetBIOS', 'RDP',
#        'ApplePush', 'MQTT', 'HTTP_Proxy', 'FacebookZero', 'SSH', 'SMTP',
#        'SOCKS', 'PostgreSQL', 'Git'], dtype=object)

# %%
db["web_service"].unique()
# Out:
# array(['DHCP', 'ICMP', 'HTTP', 'Microsoft', 'WindowsUpdate', 'Unknown',
#        'DNS', 'RX', 'TLS', 'NetBIOS', 'GoogleServices', 'Amazon', 'MSN',
#        'Yahoo', 'MS_OneDrive', 'Google', 'Dropbox', 'GMail', 'UbuntuONE',
#        'GoogleDrive', 'YouTube', 'HTTP_Proxy', 'NTP', 'Apple',
#        'AppleiTunes', 'AppleStore', 'ApplePush', 'AppleiCloud', 'IMAPS',
#        'IMO', 'Office365', 'Skype', 'Cloudflare', 'Spotify', 'LDAP',
#        'Twitter', 'Facebook', 'LinkedIn', 'Instagram', 'AmazonVideo',
#        'GooglePlus', 'Github', 'GoogleDocs', 'Teredo', 'BitTorrent',
#        'Messenger', 'WhatsApp', 'PlayStore', 'Ookla',
#        'Unencrypted_Jabber', 'SMBv23', 'Wikipedia', 'QUIC', 'Signal',
#        'CiscoVPN', 'TeamViewer', 'VNC', 'NetFlix', 'Playstation',
#        'PS_VUE', 'Xbox', 'GoogleMaps', 'GoogleHangoutDuo', 'MQTT',
#        'Radius', 'SSH', 'STUN', 'Pando_Media_Booster', 'Whois-DAS',
#        'H323', 'Webex', 'Oracle', 'DataSaver', 'Steam', 'Telegram',
# ...

# %%
db.loc[(db["web_service"] == "Twitch") & (db["category"] == "Streaming")]
# Out:
# Empty DataFrame
# Columns: [flow_key, src_ip_numeric, src_ip, src_port, dst_ip, dst_port, proto, pktTotalCount, octetTotalCount, min_ps, max_ps, avg_ps, std_dev_ps, flowStart, flowEnd, flowDuration, min_piat, max_piat, avg_piat, std_dev_piat, f_pktTotalCount, f_octetTotalCount, f_min_ps, f_max_ps, f_avg_ps, f_std_dev_ps, f_flowStart, f_flowEnd, f_flowDuration, f_min_piat, f_max_piat, f_avg_piat, f_std_dev_piat, b_pktTotalCount, b_octetTotalCount, b_min_ps, b_max_ps, b_avg_ps, b_std_dev_ps, b_flowStart, b_flowEnd, b_flowDuration, b_min_piat, b_max_piat, b_avg_piat, b_std_dev_piat, flowEndReason, category, application_protocol, web_service]
# Index: []
#
# [0 rows x 50 columns]

# %%
db.loc[db["web_service"] == "Amazon"]
# Out:
#                                  flow_key  src_ip_numeric           src_ip  \
# 175      f04ede4bcd91d6c351b6a644635d0e5e      3232266499    192.168.121.3
# 184      ab3f290b66a1318b8d3e41d995ab79fe      3232266499    192.168.121.3
# 195      a5e1f82f04e9efe686ce1e512a43c0f5      3232266499    192.168.121.3
# 203      fc3d05ae63ee01e26d0b81e3d30023bf      3232266499    192.168.121.3
# 219      b76b5bc5b3b46e0da2965dfafada44c0      3232266499    192.168.121.3
# ...                                   ...             ...              ...
# 2702297  b3a73454c5b798bdddfda8ea639e210e      3232268491  192.168.128.203
# 2702499  8f26a4a403ddd540c8fb673bd11ff609      3232268491  192.168.128.203
# 2702758  fecb5ab410605546f96a96b164e68daf      3232268491  192.168.128.203
# 2704704  73d525987cccaff482842d57d614eeda      3232268539  192.168.128.251
# 2704748  99350c4fbf66afb2cd2a4685901ce0bf      3232268539  192.168.128.251
#
#          src_port          dst_ip  dst_port  proto  pktTotalCount  \
# ...

# %%
db.loc[(db["category"] == "Unspecified") & (db["web_service"] != "Unknown")]
# Out:
# Empty DataFrame
# Columns: [flow_key, src_ip_numeric, src_ip, src_port, dst_ip, dst_port, proto, pktTotalCount, octetTotalCount, min_ps, max_ps, avg_ps, std_dev_ps, flowStart, flowEnd, flowDuration, min_piat, max_piat, avg_piat, std_dev_piat, f_pktTotalCount, f_octetTotalCount, f_min_ps, f_max_ps, f_avg_ps, f_std_dev_ps, f_flowStart, f_flowEnd, f_flowDuration, f_min_piat, f_max_piat, f_avg_piat, f_std_dev_piat, b_pktTotalCount, b_octetTotalCount, b_min_ps, b_max_ps, b_avg_ps, b_std_dev_ps, b_flowStart, b_flowEnd, b_flowDuration, b_min_piat, b_max_piat, b_avg_piat, b_std_dev_piat, flowEndReason, category, application_protocol, web_service]
# Index: []
#
# [0 rows x 50 columns]

# %%
db["web_service"].value_counts()[0:60]
# Out:
# web_service
# Google              569828
# DNS                 419915
# TLS                 259590
# Unknown             249071
# Microsoft           172392
# HTTP                152705
# Facebook            120849
# Amazon               87575
# GoogleServices       87478
# BitTorrent           70757
# YouTube              55847
# Messenger            45168
# HTTP_Proxy           33853
# Office365            24471
# NetBIOS              24016
# WhatsApp             23816
# IMO                  22858
# GMail                20728
# Dropbox              19239
# Cloudflare           16929
# Skype                15930
# Instagram            15661
# UbuntuONE            15357
# MSN                  14415
# SNMP                 13809
# WindowsUpdate        11195
# Twitter              10628
# Apple                 8266
# GoogleDrive           7666
# ICMP                  7503
# Github                6837
# GoogleHangoutDuo      6577
# NTP                   6185
# GoogleDocs            5278
# ...

# %%
db["application_protocol"].value_counts()
# Out:
# application_protocol
# Unknown         1308310
# TLS              691815
# DNS              489518
# HTTP             128373
# QUIC              70887
# STUN              13189
# IMAPS              1946
# Skype               317
# SMTPS               205
# POPS                184
# HTTP_Proxy           30
# FacebookZero         13
# SMBv23               11
# NetBIOS               9
# Git                   7
# BitTorrent            6
# MQTT                  5
# PostgreSQL            5
# SMTP                  3
# RDP                   2
# ApplePush             2
# SSH                   1
# SOCKS                 1
# Name: count, dtype: int64

# %%
db["category"].value_counts()
# Out:
# category
# Web                                  1416159
# Network                               443446
# Unspecified                           249071
# SocialNetwork                         150941
# Chat                                   75532
# Download-FileTransfer-FileSharing      70830
# Media                                  63901
# Cloud                                  50465
# VoIP                                   47010
# Collaborative                          39037
# System                                 36951
# Email                                  22708
# SoftwareUpdate                         16500
# Video                                   7844
# Music                                   3545
# RemoteAccess                            3351
# Game                                    2856
# RPC                                     2205
# Database                                 812
# Streaming                                714
# VPN                                      536
# ...
